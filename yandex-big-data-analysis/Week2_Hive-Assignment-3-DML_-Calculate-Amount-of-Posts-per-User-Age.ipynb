# %%
# %%writefile assigment_reply.hql
#
# USE stackoverflow_;
#
# SELECT
#     users.age,
#     sum(if(post_type_id = 1, 1, 0)),
#     sum(if(post_type_id = 2, 1, 0))
# FROM
#     posts
# JOIN
#     users ON posts.owner_user_id = users.id
# WHERE
#     post_type_id IN (1,2)
#     AND users.age IS NOT NULL
# GROUP BY users.age
# ORDER BY users.age;
# Out:
# Writing assigment_reply.hql

# %%
# !hive -f assigment_reply.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# OK
# Time taken: 1.11 seconds
# Query ID = jovyan_20190515190707_d0f762d1-988a-4730-ac1e-7a9f453a96c3
# Total jobs = 2
# Execution log at: /tmp/jovyan/jovyan_20190515190707_d0f762d1-988a-4730-ac1e-7a9f453a96c3.log
# 2019-05-15 07:07:09	Starting to launch local task to process map join;	maximum memory = 477626368
# 2019-05-15 07:07:11	Dump the side-table for tag: 1 with group count: 5951 into file: file:/tmp/jovyan/159d7375-af8f-4ba5-869c-7dea7189f07d/hive_2019-05-15_19-07-00_042_6919854244033256903-1/-local-10005/HashTable-Stage-2/MapJoin-mapfile01--.hashtable
# 2019-05-15 07:07:11	Uploaded 1 File to: file:/tmp/jovyan/159d7375-af8f-4ba5-869c-7dea7189f07d/hive_2019-05-15_19-07-00_042_6919854244033256903-1/-local-10005/HashTable-Stage-2/MapJoin-mapfile01--.hashtable (137665 bytes)
# 2019-05-15 07:07:11	End of local task; Time Taken: 2.125 sec.
# Execution completed successfully
# MapredLocal task succeeded
# Launching Job 1 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1557847019885_0045, Tracking URL = http://b1dfc078ce9b:8088/proxy/application_1557847019885_0045/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1557847019885_0045
# Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# 2019-05-15 19:07:26,616 Stage-2 map = 0%,  reduce = 0%
# 2019-05-15 19:07:37,686 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 9.06 sec
# 2019-05-15 19:07:46,370 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 12.42 sec
# MapReduce Total cumulative CPU time: 12 seconds 420 msec
# Ended Job = job_1557847019885_0045
# Launching Job 2 out of 2
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1557847019885_0046, Tracking URL = http://b1dfc078ce9b:8088/proxy/application_1557847019885_0046/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1557847019885_0046
# Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
# 2019-05-15 19:08:04,085 Stage-3 map = 0%,  reduce = 0%
# 2019-05-15 19:08:11,750 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 2.53 sec
# 2019-05-15 19:08:19,269 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 5.6 sec
# MapReduce Total cumulative CPU time: 5 seconds 600 msec
# Ended Job = job_1557847019885_0046
# MapReduce Jobs Launched:
# Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 12.42 sec   HDFS Read: 2261833 HDFS Write: 1056 SUCCESS
# Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 5.6 sec   HDFS Read: 5627 HDFS Write: 376 SUCCESS
# Total MapReduce CPU Time Spent: 18 seconds 20 msec
# OK
# 14	1	0
# 15	1	2
# 16	2	0
# 17	0	1
# 18	4	1
# 19	1	1
# 20	0	2
# 21	11	24
# 22	6	18
# 23	12	15
# 24	16	27
# 25	20	33
# 26	23	44
# 27	28	56
# 28	24	37
# 29	24	66
# 30	26	67
# 31	17	33
# 32	13	48
# 33	11	40
# 34	24	36
# 35	12	42
# 36	8	64
# 37	9	35
# 38	6	17
# 39	3	7
# 40	1	13
# 41	5	20
# 42	5	22
# 43	2	26
# 44	7	35
# 45	1	4
# 46	7	9
# 47	1	1
# 48	1	1
# 49	1	26
# 50	1	26
# 51	4	5
# 52	0	2
# 53	0	2
# 54	0	1
# 57	0	3
# 58	1	57
# 60	0	6
# 61	0	3
# 64	2	1
# 86	0	1
# 96	3	1
# Time taken: 80.4 seconds, Fetched: 48 row(s)
